# %% [markdown]
# # ASX OHLCV Lake Check
#
# This notebook inspects the ASX200 lake flow in MinIO. It validates the request config, counts raw and conformed objects, reads the curated parquet panel, and writes a compact summary artifact.

# %%
from __future__ import annotations

import io
import json
from datetime import datetime, timezone
from pathlib import Path
from urllib import request

import boto3
import pandas as pd
import pyarrow.parquet as pq

CONFIG_PATH = Path("/home/jovyan/config/asx/asx_data_request.json")
OUTPUT_PATH = Path("/home/jovyan/data/asx_ohlcv_summary.json")
MINIO_ENDPOINT = "http://minio:9000"
MINIO_ACCESS_KEY = "minioadmin"
MINIO_SECRET_KEY = "minioadmin"
MINIO_REGION = "local-01"
RAW_BUCKET = "raw"
CONFORMED_BUCKET = "conformed"
CURATED_BUCKET = "curated"
TRINO_URL = "http://trino:8080/v1/statement"
TRINO_SQL = (
    "SELECT ticker, run_date, row_count, start_trade_date, end_trade_date, min_close, max_close, latest_close, average_volume, generated_at "
    "FROM demo.asx_ohlcv_summary ORDER BY ticker"
)

if not CONFIG_PATH.is_file():
    raise FileNotFoundError(f"ASX request config was not found at canonical notebook path {CONFIG_PATH}.")

config = json.loads(CONFIG_PATH.read_text(encoding="utf-8"))
dataset_id = str(config["dataset_id"])
exchange = str(config["exchange"])
prefix = f"tabular/{dataset_id}/exchange={exchange}/"
curated_key = f"{prefix}asx_ohlcv_panel_curated.parquet"

s3 = boto3.client(
    "s3",
    endpoint_url=MINIO_ENDPOINT,
    aws_access_key_id=MINIO_ACCESS_KEY,
    aws_secret_access_key=MINIO_SECRET_KEY,
    region_name=MINIO_REGION,
)

print(f"Config path: {CONFIG_PATH}")
print(f"Lake prefix: {prefix}")
config
# Out:
# Config path: /home/jovyan/config/asx/asx_data_request.json
# Lake prefix: tabular/market_ohlcv_daily_v2/exchange=ASX/
# {'request_id': 'asx200-ohlcv-v2-10y-rolling-2026-07-20',
#  'dataset_id': 'market_ohlcv_daily_v2',
#  'exchange': 'ASX',
#  'currency': 'AUD',
#  'ticker_list': ['360',
#   '4DX',
#   'A2M',
#   'AAI',
#   'AFI',
#   'AGL',
#   'AIA',
#   'ALD',
#   'ALK',
#   'ALL',
#   'ALQ',
#   'ALX',
#   'AMC',
#   'AMP',
#   'ANN',
#   'ANZ',
#   'APA',
#   'APE',
#   'ARB',
#   'ARG',
#   'ASB',
#   'ASK',
#   'ASX',
#   'AUB',
#   'AZJ',
#   'BEN',
#   'BFL',
#   'BGA',
#   'BGL',
#   'BHP',
#   'BOQ',
#   'BPT',
#   'BRG',
#   'BSL',
#   'BWP',
#   'BXB',
#   'CAR',
#   'CBA',
#   'CDA',
#   'CEN',
#   'CGF',
#   'CHC',
#   'CIA',
#   'CIP',
#   'CLW',
#   'CMM',
#   'CNU',
#   'COH',
#   'COL',
#   'CPU',
#   'CQR',
#   'CSC',
#   'CSL',
#   'CTD',
#   'CWY',
#   'CYL',
#   'DBI',
#   'DNL',
#   'DOW',
#   'DRO',
#   'DRR',
#   'DVP',
#   'DXS',
#   'DYL',
#   'EBO',
#   'EDV',
#   'ELV',
#   'EMR',
#   'EOS',
#   'EVN',
#   'EVT',
#   'FBU',
#   'FFM',
#   'FLT',
#   'FMG',
#   'FPH',
#   'FRW',
#   'GDG',
#   'GGP',
#   'GMD',
#   'GMG',
#   'GNE',
#   'GPT',
#   'GQG',
#   'HDN',
#   'HUB',
#   'HVN',
#   'IAG',
#   'IFT',
#   'IGO',
#   'ILU',
#   'IMD',
#   'JBH',
#   'KCN',
#   'JHX',
#   'L1G',
#   'LLC',
#   'LNW',
#   'LOV',
#   'LSF',
#   'LTR',
#   'LYC',
#   'MCY',
#   'MEZ',
#   'MFF',
#   'MFG',
#   'MGR',
#   'MI6',
#   'MIN',
#   'MND',
#   'MPL',
#   'MQG',
#   'MSB',
#   'MTS',
#   'MXT',
#   'NAB',
#   'NEM',
#   'NHC',
#   'NHF',
#   'NIC',
#   'NST',
#   'NWH',
#   'NWL',
#   'NWS',
#   'NXG',
#   'NXT',
#   'OBM',
#   'ORA',
#   'ORG',
#   'ORI',
#   'PDI',
#   'PDN',
#   'PLS',
#   'PME',
#   'PMV',
#   'PNI',
#   'PPT',
#   'PRN',
#   'PRU',
#   'PXA',
#   'QAN',
#   'QBE',
#   'RDX',
#   'REA',
#   'REG',
#   'REH',
#   'RGN',
#   'RHC',
#   'RIO',
#   'RMD',
#   'RMS',
#   'RRL',
#   'RSG',
#   'RWC',
#   'RYM',
#   'S32',
#   'SCG',
#   'SDF',
#   'SEK',
#   'SFR',
#   'SGH',
#   'SGM',
#   'SGP',
#   'SHL',
#   'SIG',
#   'SMR',
#   'SNZ',
#   'SOL',
#   'SPK',
#   'STO',
#   'SUL',
#   'SUN',
#   'TAH',
#   'TCL',
#   'TLC',
#   'TLS',
#   'TLX',
#   'TNE',
#   'TPG',
#   'TUA',
#   'TWE',
#   'VAU',
#   'VCX',
#   'VEA',
#   'VGN',
#   'VNT',
#   'WAF',
#   'WAM',
#   'WBC',
#   'WDS',
#   'WES',
#   'WGX',
#   'WHC',
#   'WLE',
#   'WOR',
#   'WOW',
#   'WTC',
#   'XRO',
#   'YAL',
#   'ZIM',
#   'ZIP'],
#  'vendor_symbol_map': {'360': '360.AX',
#   '4DX': '4DX.AX',
#   'A2M': 'A2M.AX',
#   'AAI': 'AAI.AX',
#   'AFI': 'AFI.AX',
#   'AGL': 'AGL.AX',
#   'AIA': 'AIA.AX',
#   'ALD': 'ALD.AX',
#   'ALK': 'ALK.AX',
#   'ALL': 'ALL.AX',
#   'ALQ': 'ALQ.AX',
#   'ALX': 'ALX.AX',
#   'AMC': 'AMC.AX',
#   'AMP': 'AMP.AX',
#   'ANN': 'ANN.AX',
#   'ANZ': 'ANZ.AX',
#   'APA': 'APA.AX',
#   'APE': 'APE.AX',
#   'ARB': 'ARB.AX',
#   'ARG': 'ARG.AX',
#   'ASB': 'ASB.AX',
#   'ASK': 'ASK.AX',
#   'ASX': 'ASX.AX',
#   'AUB': 'AUB.AX',
#   'AZJ': 'AZJ.AX',
#   'BEN': 'BEN.AX',
#   'BFL': 'BFL.AX',
#   'BGA': 'BGA.AX',
#   'BGL': 'BGL.AX',
#   'BHP': 'BHP.AX',
#   'BOQ': 'BOQ.AX',
#   'BPT': 'BPT.AX',
#   'BRG': 'BRG.AX',
#   'BSL': 'BSL.AX',
#   'BWP': 'BWP.AX',
#   'BXB': 'BXB.AX',
#   'CAR': 'CAR.AX',
#   'CBA': 'CBA.AX',
#   'CDA': 'CDA.AX',
#   'CEN': 'CEN.AX',
#   'CGF': 'CGF.AX',
#   'CHC': 'CHC.AX',
#   'CIA': 'CIA.AX',
#   'CIP': 'CIP.AX',
#   'CLW': 'CLW.AX',
#   'CMM': 'CMM.AX',
#   'CNU': 'CNU.AX',
#   'COH': 'COH.AX',
#   'COL': 'COL.AX',
#   'CPU': 'CPU.AX',
#   'CQR': 'CQR.AX',
#   'CSC': 'CSC.AX',
#   'CSL': 'CSL.AX',
#   'CTD': 'CTD.AX',
#   'CWY': 'CWY.AX',
#   'CYL': 'CYL.AX',
#   'DBI': 'DBI.AX',
#   'DNL': 'DNL.AX',
#   'DOW': 'DOW.AX',
#   'DRO': 'DRO.AX',
#   'DRR': 'DRR.AX',
#   'DVP': 'DVP.AX',
#   'DXS': 'DXS.AX',
#   'DYL': 'DYL.AX',
#   'EBO': 'EBO.AX',
#   'EDV': 'EDV.AX',
#   'ELV': 'ELV.AX',
#   'EMR': 'EMR.AX',
#   'EOS': 'EOS.AX',
#   'EVN': 'EVN.AX',
#   'EVT': 'EVT.AX',
#   'FBU': 'FBU.AX',
#   'FFM': 'FFM.AX',
#   'FLT': 'FLT.AX',
#   'FMG': 'FMG.AX',
#   'FPH': 'FPH.AX',
#   'FRW': 'FRW.AX',
#   'GDG': 'GDG.AX',
#   'GGP': 'GGP.AX',
#   'GMD': 'GMD.AX',
#   'GMG': 'GMG.AX',
#   'GNE': 'GNE.AX',
#   'GPT': 'GPT.AX',
#   'GQG': 'GQG.AX',
#   'HDN': 'HDN.AX',
#   'HUB': 'HUB.AX',
#   'HVN': 'HVN.AX',
#   'IAG': 'IAG.AX',
#   'IFT': 'IFT.AX',
#   'IGO': 'IGO.AX',
#   'ILU': 'ILU.AX',
#   'IMD': 'IMD.AX',
#   'JBH': 'JBH.AX',
#   'KCN': 'KCN.AX',
#   'JHX': 'JHX.AX',
#   'L1G': 'L1G.AX',
#   'LLC': 'LLC.AX',
#   'LNW': 'LNW.AX',
#   'LOV': 'LOV.AX',
#   'LSF': 'LSF.AX',
#   'LTR': 'LTR.AX',
#   'LYC': 'LYC.AX',
#   'MCY': 'MCY.AX',
#   'MEZ': 'MEZ.AX',
#   'MFF': 'MFF.AX',
#   'MFG': 'MFG.AX',
#   'MGR': 'MGR.AX',
#   'MI6': 'MI6.AX',
#   'MIN': 'MIN.AX',
#   'MND': 'MND.AX',
#   'MPL': 'MPL.AX',
#   'MQG': 'MQG.AX',
#   'MSB': 'MSB.AX',
#   'MTS': 'MTS.AX',
#   'MXT': 'MXT.AX',
#   'NAB': 'NAB.AX',
#   'NEM': 'NEM.AX',
#   'NHC': 'NHC.AX',
#   'NHF': 'NHF.AX',
#   'NIC': 'NIC.AX',
#   'NST': 'NST.AX',
#   'NWH': 'NWH.AX',
#   'NWL': 'NWL.AX',
#   'NWS': 'NWS.AX',
#   'NXG': 'NXG.AX',
#   'NXT': 'NXT.AX',
#   'OBM': 'OBM.AX',
#   'ORA': 'ORA.AX',
#   'ORG': 'ORG.AX',
#   'ORI': 'ORI.AX',
#   'PDI': 'PDI.AX',
#   'PDN': 'PDN.AX',
#   'PLS': 'PLS.AX',
#   'PME': 'PME.AX',
#   'PMV': 'PMV.AX',
#   'PNI': 'PNI.AX',
#   'PPT': 'PPT.AX',
#   'PRN': 'PRN.AX',
#   'PRU': 'PRU.AX',
#   'PXA': 'PXA.AX',
#   'QAN': 'QAN.AX',
#   'QBE': 'QBE.AX',
#   'RDX': 'RDX.AX',
#   'REA': 'REA.AX',
#   'REG': 'REG.AX',
#   'REH': 'REH.AX',
#   'RGN': 'RGN.AX',
#   'RHC': 'RHC.AX',
#   'RIO': 'RIO.AX',
#   'RMD': 'RMD.AX',
#   'RMS': 'RMS.AX',
#   'RRL': 'RRL.AX',
#   'RSG': 'RSG.AX',
#   'RWC': 'RWC.AX',
#   'RYM': 'RYM.AX',
#   'S32': 'S32.AX',
#   'SCG': 'SCG.AX',
#   'SDF': 'SDF.AX',
#   'SEK': 'SEK.AX',
#   'SFR': 'SFR.AX',
#   'SGH': 'SGH.AX',
#   'SGM': 'SGM.AX',
#   'SGP': 'SGP.AX',
#   'SHL': 'SHL.AX',
#   'SIG': 'SIG.AX',
#   'SMR': 'SMR.AX',
#   'SNZ': 'SNZ.AX',
#   'SOL': 'SOL.AX',
#   'SPK': 'SPK.AX',
#   'STO': 'STO.AX',
#   'SUL': 'SUL.AX',
#   'SUN': 'SUN.AX',
#   'TAH': 'TAH.AX',
#   'TCL': 'TCL.AX',
#   'TLC': 'TLC.AX',
#   'TLS': 'TLS.AX',
#   'TLX': 'TLX.AX',
#   'TNE': 'TNE.AX',
#   'TPG': 'TPG.AX',
#   'TUA': 'TUA.AX',
#   'TWE': 'TWE.AX',
#   'VAU': 'VAU.AX',
#   'VCX': 'VCX.AX',
#   'VEA': 'VEA.AX',
#   'VGN': 'VGN.AX',
#   'VNT': 'VNT.AX',
#   'WAF': 'WAF.AX',
#   'WAM': 'WAM.AX',
#   'WBC': 'WBC.AX',
#   'WDS': 'WDS.AX',
#   'WES': 'WES.AX',
#   'WGX': 'WGX.AX',
#   'WHC': 'WHC.AX',
#   'WLE': 'WLE.AX',
#   'WOR': 'WOR.AX',
#   'WOW': 'WOW.AX',
#   'WTC': 'WTC.AX',
#   'XRO': 'XRO.AX',
#   'YAL': 'YAL.AX',
#   'ZIM': 'ZIM.AX',
#   'ZIP': 'ZIP.AX'},
#  'earliest_start_date': None,
#  'lookback_days': 3650,
#  'end_date': None}

# %%
def list_keys(bucket: str, prefix: str) -> list[str]:
    keys = []
    token = None
    while True:
        kwargs = {"Bucket": bucket, "Prefix": prefix, "MaxKeys": 1000}
        if token:
            kwargs["ContinuationToken"] = token
        response = s3.list_objects_v2(**kwargs)
        keys.extend(obj["Key"] for obj in response.get("Contents", []))
        if not response.get("IsTruncated"):
            break
        token = response.get("NextContinuationToken")
    return keys


def run_trino_query(sql: str) -> list[dict[str, object]]:
    headers = {"X-Trino-User": "jovyan", "X-Trino-Catalog": "demo", "X-Trino-Schema": "demo"}
    req = request.Request(TRINO_URL, data=sql.encode("utf-8"), headers=headers, method="POST")
    rows = []
    columns = []

    with request.urlopen(req, timeout=30) as response:
        payload = json.loads(response.read().decode("utf-8"))

    while True:
        if not columns and payload.get("columns"):
            columns = [column["name"] for column in payload["columns"]]
        rows.extend(payload.get("data", []))
        next_uri = payload.get("nextUri")
        if not next_uri:
            break
        with request.urlopen(next_uri, timeout=30) as response:
            payload = json.loads(response.read().decode("utf-8"))

    return [dict(zip(columns, row)) for row in rows]

raw_keys = [key for key in list_keys(RAW_BUCKET, prefix) if key.endswith(".csv")]
conformed_keys = [key for key in list_keys(CONFORMED_BUCKET, prefix) if key.endswith(".parquet")]
curated_keys = [key for key in list_keys(CURATED_BUCKET, prefix) if key.endswith(".parquet")]

lake_summary = {
    "expected_ticker_count": len(config["ticker_list"]),
    "raw_object_count": len(raw_keys),
    "conformed_object_count": len(conformed_keys),
    "curated_object_count": len(curated_keys),
    "sample_raw_keys": raw_keys[:3],
    "sample_conformed_keys": conformed_keys[:3],
    "sample_curated_keys": curated_keys[:3],
}
lake_summary
# Out:
# {'expected_ticker_count': 201,
#  'raw_object_count': 201,
#  'conformed_object_count': 201,
#  'curated_object_count': 1,
#  'sample_raw_keys': ['tabular/market_ohlcv_daily_v2/exchange=ASX/ticker=360.csv',
#   'tabular/market_ohlcv_daily_v2/exchange=ASX/ticker=4DX.csv',
#   'tabular/market_ohlcv_daily_v2/exchange=ASX/ticker=A2M.csv'],
#  'sample_conformed_keys': ['tabular/market_ohlcv_daily_v2/exchange=ASX/ticker=360.parquet',
#   'tabular/market_ohlcv_daily_v2/exchange=ASX/ticker=4DX.parquet',
#   'tabular/market_ohlcv_daily_v2/exchange=ASX/ticker=A2M.parquet'],
#  'sample_curated_keys': ['tabular/market_ohlcv_daily_v2/exchange=ASX/asx_ohlcv_panel_curated.parquet']}

# %%
curated_response = s3.get_object(Bucket=CURATED_BUCKET, Key=curated_key)
curated_table = pq.read_table(io.BytesIO(curated_response["Body"].read()))
df = curated_table.to_pandas()
df["trade_date"] = pd.to_datetime(df["trade_date"], errors="coerce")
df = df.dropna(subset=["trade_date"]).sort_values(["ticker", "trade_date"]).reset_index(drop=True)
df["close"] = pd.to_numeric(df["close"], errors="coerce")
df["volume"] = pd.to_numeric(df["volume"], errors="coerce")
df["daily_return"] = df.groupby("ticker")["close"].pct_change()

dataset_summary = {
    "rows": int(len(df)),
    "tickers": int(df["ticker"].nunique()),
    "date_min": df["trade_date"].min().date().isoformat(),
    "date_max": df["trade_date"].max().date().isoformat(),
    "null_close_rows": int(df["close"].isna().sum()),
    "null_volume_rows": int(df["volume"].isna().sum()),
}

latest_close = (
    df.groupby("ticker", as_index=False)
    .tail(1)
    .loc[:, ["ticker", "trade_date", "close", "daily_return", "volume"]]
    .sort_values("ticker")
)

trino_rows = []
trino_error = None
try:
    trino_rows = run_trino_query(TRINO_SQL)
except Exception as exc:
    trino_error = str(exc)

dataset_summary
# Out:
# {'rows': 466753,
#  'tickers': 201,
#  'date_min': '2016-08-24',
#  'date_max': '2026-08-21',
#  'null_close_rows': 0,
#  'null_volume_rows': 0}

# %%
output_payload = {
    "generated_at": datetime.now(timezone.utc).replace(microsecond=0).isoformat().replace("+00:00", "Z"),
    "config_path": str(CONFIG_PATH),
    "config": config,
    "lake_summary": lake_summary,
    "dataset_summary": dataset_summary,
    "latest_close_records": latest_close.to_dict(orient="records"),
    "trino_query": TRINO_SQL,
    "trino_row_count": len(trino_rows),
    "trino_error": trino_error,
    "trino_rows": trino_rows,
}

OUTPUT_PATH.write_text(json.dumps(output_payload, indent=2, sort_keys=True, default=str), encoding="utf-8")
print(f"Summary written to {OUTPUT_PATH}")
output_payload
# Out:
# Summary written to /home/jovyan/data/asx_ohlcv_summary.json
# {'generated_at': '2026-08-21T03:01:06Z',
#  'config_path': '/home/jovyan/config/asx/asx_data_request.json',
#  'config': {'request_id': 'asx200-ohlcv-v2-10y-rolling-2026-07-20',
#   'dataset_id': 'market_ohlcv_daily_v2',
#   'exchange': 'ASX',
#   'currency': 'AUD',
#   'ticker_list': ['360',
#    '4DX',
#    'A2M',
#    'AAI',
#    'AFI',
#    'AGL',
#    'AIA',
#    'ALD',
#    'ALK',
#    'ALL',
#    'ALQ',
#    'ALX',
#    'AMC',
#    'AMP',
#    'ANN',
#    'ANZ',
#    'APA',
#    'APE',
#    'ARB',
#    'ARG',
#    'ASB',
#    'ASK',
#    'ASX',
#    'AUB',
#    'AZJ',
#    'BEN',
#    'BFL',
#    'BGA',
#    'BGL',
#    'BHP',
#    'BOQ',
#    'BPT',
#    'BRG',
#    'BSL',
#    'BWP',
#    'BXB',
#    'CAR',
#    'CBA',
#    'CDA',
#    'CEN',
#    'CGF',
#    'CHC',
#    'CIA',
#    'CIP',
#    'CLW',
#    'CMM',
#    'CNU',
#    'COH',
#    'COL',
#    'CPU',
#    'CQR',
#    'CSC',
#    'CSL',
#    'CTD',
#    'CWY',
#    'CYL',
#    'DBI',
#    'DNL',
#    'DOW',
#    'DRO',
#    'DRR',
#    'DVP',
#    'DXS',
#    'DYL',
#    'EBO',
#    'EDV',
#    'ELV',
#    'EMR',
#    'EOS',
#    'EVN',
#    'EVT',
#    'FBU',
#    'FFM',
#    'FLT',
#    'FMG',
#    'FPH',
#    'FRW',
#    'GDG',
#    'GGP',
#    'GMD',
#    'GMG',
#    'GNE',
#    'GPT',
#    'GQG',
#    'HDN',
#    'HUB',
#    'HVN',
#    'IAG',
#    'IFT',
#    'IGO',
#    'ILU',
#    'IMD',
#    'JBH',
#    'KCN',
#    'JHX',
#    'L1G',
#    'LLC',
#    'LNW',
#    'LOV',
#    'LSF',
#    'LTR',
#    'LYC',
#    'MCY',
#    'MEZ',
#    'MFF',
#    'MFG',
#    'MGR',
#    'MI6',
#    'MIN',
#    'MND',
#    'MPL',
#    'MQG',
#    'MSB',
#    'MTS',
#    'MXT',
#    'NAB',
#    'NEM',
#    'NHC',
#    'NHF',
#    'NIC',
#    'NST',
#    'NWH',
#    'NWL',
#    'NWS',
#    'NXG',
#    'NXT',
#    'OBM',
#    'ORA',
#    'ORG',
#    'ORI',
#    'PDI',
#    'PDN',
#    'PLS',
#    'PME',
#    'PMV',
#    'PNI',
#    'PPT',
#    'PRN',
#    'PRU',
#    'PXA',
#    'QAN',
#    'QBE',
#    'RDX',
#    'REA',
#    'REG',
#    'REH',
#    'RGN',
#    'RHC',
#    'RIO',
#    'RMD',
#    'RMS',
#    'RRL',
#    'RSG',
#    'RWC',
#    'RYM',
#    'S32',
#    'SCG',
#    'SDF',
#    'SEK',
#    'SFR',
#    'SGH',
#    'SGM',
#    'SGP',
#    'SHL',
#    'SIG',
#    'SMR',
#    'SNZ',
#    'SOL',
#    'SPK',
#    'STO',
#    'SUL',
#    'SUN',
#    'TAH',
#    'TCL',
#    'TLC',
#    'TLS',
#    'TLX',
#    'TNE',
#    'TPG',
#    'TUA',
#    'TWE',
#    'VAU',
#    'VCX',
#    'VEA',
#    'VGN',
#    'VNT',
#    'WAF',
#    'WAM',
#    'WBC',
#    'WDS',
#    'WES',
#    'WGX',
#    'WHC',
#    'WLE',
#    'WOR',
#    'WOW',
#    'WTC',
#    'XRO',
#    'YAL',
#    'ZIM',
#    'ZIP'],
#   'vendor_symbol_map': {'360': '360.AX',
#    '4DX': '4DX.AX',
#    'A2M': 'A2M.AX',
#    'AAI': 'AAI.AX',
#    'AFI': 'AFI.AX',
#    'AGL': 'AGL.AX',
#    'AIA': 'AIA.AX',
#    'ALD': 'ALD.AX',
#    'ALK': 'ALK.AX',
#    'ALL': 'ALL.AX',
#    'ALQ': 'ALQ.AX',
#    'ALX': 'ALX.AX',
#    'AMC': 'AMC.AX',
#    'AMP': 'AMP.AX',
#    'ANN': 'ANN.AX',
#    'ANZ': 'ANZ.AX',
#    'APA': 'APA.AX',
#    'APE': 'APE.AX',
#    'ARB': 'ARB.AX',
#    'ARG': 'ARG.AX',
#    'ASB': 'ASB.AX',
#    'ASK': 'ASK.AX',
#    'ASX': 'ASX.AX',
#    'AUB': 'AUB.AX',
#    'AZJ': 'AZJ.AX',
#    'BEN': 'BEN.AX',
#    'BFL': 'BFL.AX',
#    'BGA': 'BGA.AX',
#    'BGL': 'BGL.AX',
#    'BHP': 'BHP.AX',
#    'BOQ': 'BOQ.AX',
#    'BPT': 'BPT.AX',
#    'BRG': 'BRG.AX',
#    'BSL': 'BSL.AX',
#    'BWP': 'BWP.AX',
#    'BXB': 'BXB.AX',
#    'CAR': 'CAR.AX',
#    'CBA': 'CBA.AX',
#    'CDA': 'CDA.AX',
#    'CEN': 'CEN.AX',
#    'CGF': 'CGF.AX',
#    'CHC': 'CHC.AX',
#    'CIA': 'CIA.AX',
#    'CIP': 'CIP.AX',
#    'CLW': 'CLW.AX',
#    'CMM': 'CMM.AX',
#    'CNU': 'CNU.AX',
#    'COH': 'COH.AX',
#    'COL': 'COL.AX',
#    'CPU': 'CPU.AX',
#    'CQR': 'CQR.AX',
#    'CSC': 'CSC.AX',
#    'CSL': 'CSL.AX',
#    'CTD': 'CTD.AX',
#    'CWY': 'CWY.AX',
#    'CYL': 'CYL.AX',
#    'DBI': 'DBI.AX',
#    'DNL': 'DNL.AX',
#    'DOW': 'DOW.AX',
#    'DRO': 'DRO.AX',
#    'DRR': 'DRR.AX',
#    'DVP': 'DVP.AX',
#    'DXS': 'DXS.AX',
#    'DYL': 'DYL.AX',
#    'EBO': 'EBO.AX',
#    'EDV': 'EDV.AX',
#    'ELV': 'ELV.AX',
#    'EMR': 'EMR.AX',
#    'EOS': 'EOS.AX',
#    'EVN': 'EVN.AX',
#    'EVT': 'EVT.AX',
#    'FBU': 'FBU.AX',
#    'FFM': 'FFM.AX',
#    'FLT': 'FLT.AX',
#    'FMG': 'FMG.AX',
#    'FPH': 'FPH.AX',
#    'FRW': 'FRW.AX',
#    'GDG': 'GDG.AX',
#    'GGP': 'GGP.AX',
#    'GMD': 'GMD.AX',
#    'GMG': 'GMG.AX',
#    'GNE': 'GNE.AX',
#    'GPT': 'GPT.AX',
#    'GQG': 'GQG.AX',
#    'HDN': 'HDN.AX',
#    'HUB': 'HUB.AX',
#    'HVN': 'HVN.AX',
#    'IAG': 'IAG.AX',
#    'IFT': 'IFT.AX',
#    'IGO': 'IGO.AX',
#    'ILU': 'ILU.AX',
#    'IMD': 'IMD.AX',
#    'JBH': 'JBH.AX',
#    'KCN': 'KCN.AX',
#    'JHX': 'JHX.AX',
#    'L1G': 'L1G.AX',
#    'LLC': 'LLC.AX',
#    'LNW': 'LNW.AX',
#    'LOV': 'LOV.AX',
#    'LSF': 'LSF.AX',
#    'LTR': 'LTR.AX',
#    'LYC': 'LYC.AX',
#    'MCY': 'MCY.AX',
#    'MEZ': 'MEZ.AX',
#    'MFF': 'MFF.AX',
#    'MFG': 'MFG.AX',
#    'MGR': 'MGR.AX',
#    'MI6': 'MI6.AX',
#    'MIN': 'MIN.AX',
#    'MND': 'MND.AX',
#    'MPL': 'MPL.AX',
#    'MQG': 'MQG.AX',
#    'MSB': 'MSB.AX',
#    'MTS': 'MTS.AX',
#    'MXT': 'MXT.AX',
#    'NAB': 'NAB.AX',
#    'NEM': 'NEM.AX',
#    'NHC': 'NHC.AX',
#    'NHF': 'NHF.AX',
#    'NIC': 'NIC.AX',
#    'NST': 'NST.AX',
#    'NWH': 'NWH.AX',
#    'NWL': 'NWL.AX',
#    'NWS': 'NWS.AX',
#    'NXG': 'NXG.AX',
#    'NXT': 'NXT.AX',
#    'OBM': 'OBM.AX',
#    'ORA': 'ORA.AX',
#    'ORG': 'ORG.AX',
#    'ORI': 'ORI.AX',
#    'PDI': 'PDI.AX',
#    'PDN': 'PDN.AX',
#    'PLS': 'PLS.AX',
#    'PME': 'PME.AX',
#    'PMV': 'PMV.AX',
#    'PNI': 'PNI.AX',
#    'PPT': 'PPT.AX',
#    'PRN': 'PRN.AX',
#    'PRU': 'PRU.AX',
#    'PXA': 'PXA.AX',
#    'QAN': 'QAN.AX',
#    'QBE': 'QBE.AX',
#    'RDX': 'RDX.AX',
#    'REA': 'REA.AX',
#    'REG': 'REG.AX',
#    'REH': 'REH.AX',
#    'RGN': 'RGN.AX',
#    'RHC': 'RHC.AX',
#    'RIO': 'RIO.AX',
#    'RMD': 'RMD.AX',
#    'RMS': 'RMS.AX',
#    'RRL': 'RRL.AX',
#    'RSG': 'RSG.AX',
#    'RWC': 'RWC.AX',
#    'RYM': 'RYM.AX',
#    'S32': 'S32.AX',
#    'SCG': 'SCG.AX',
#    'SDF': 'SDF.AX',
#    'SEK': 'SEK.AX',
#    'SFR': 'SFR.AX',
#    'SGH': 'SGH.AX',
#    'SGM': 'SGM.AX',
#    'SGP': 'SGP.AX',
#    'SHL': 'SHL.AX',
#    'SIG': 'SIG.AX',
#    'SMR': 'SMR.AX',
#    'SNZ': 'SNZ.AX',
#    'SOL': 'SOL.AX',
#    'SPK': 'SPK.AX',
#    'STO': 'STO.AX',
#    'SUL': 'SUL.AX',
#    'SUN': 'SUN.AX',
#    'TAH': 'TAH.AX',
#    'TCL': 'TCL.AX',
#    'TLC': 'TLC.AX',
#    'TLS': 'TLS.AX',
#    'TLX': 'TLX.AX',
#    'TNE': 'TNE.AX',
#    'TPG': 'TPG.AX',
#    'TUA': 'TUA.AX',
#    'TWE': 'TWE.AX',
#    'VAU': 'VAU.AX',
#    'VCX': 'VCX.AX',
#    'VEA': 'VEA.AX',
#    'VGN': 'VGN.AX',
#    'VNT': 'VNT.AX',
#    'WAF': 'WAF.AX',
#    'WAM': 'WAM.AX',
#    'WBC': 'WBC.AX',
#    'WDS': 'WDS.AX',
#    'WES': 'WES.AX',
#    'WGX': 'WGX.AX',
#    'WHC': 'WHC.AX',
#    'WLE': 'WLE.AX',
#    'WOR': 'WOR.AX',
#    'WOW': 'WOW.AX',
#    'WTC': 'WTC.AX',
#    'XRO': 'XRO.AX',
#    'YAL': 'YAL.AX',
#    'ZIM': 'ZIM.AX',
#    'ZIP': 'ZIP.AX'},
#   'earliest_start_date': None,
#   'lookback_days': 3650,
#   'end_date': None},
#  'lake_summary': {'expected_ticker_count': 201,
#   'raw_object_count': 201,
#   'conformed_object_count': 201,
#   'curated_object_count': 1,
#   'sample_raw_keys': ['tabular/market_ohlcv_daily_v2/exchange=ASX/ticker=360.csv',
#    'tabular/market_ohlcv_daily_v2/exchange=ASX/ticker=4DX.csv',
#    'tabular/market_ohlcv_daily_v2/exchange=ASX/ticker=A2M.csv'],
#   'sample_conformed_keys': ['tabular/market_ohlcv_daily_v2/exchange=ASX/ticker=360.parquet',
#    'tabular/market_ohlcv_daily_v2/exchange=ASX/ticker=4DX.parquet',
#    'tabular/market_ohlcv_daily_v2/exchange=ASX/ticker=A2M.parquet'],
#   'sample_curated_keys': ['tabular/market_ohlcv_daily_v2/exchange=ASX/asx_ohlcv_panel_curated.parquet']},
#  'dataset_summary': {'rows': 466753,
#   'tickers': 201,
#   'date_min': '2016-08-24',
#   'date_max': '2026-08-21',
#   'null_close_rows': 0,
#   'null_volume_rows': 0},
#  'latest_close_records': [{'ticker': '360',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 20.93000030517578,
#    'daily_return': -0.008996237050552747,
#    'volume': 777503},
#   {'ticker': '4DX',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 3.930000066757202,
#    'daily_return': -0.022388038456798376,
#    'volume': 1506974},
#   {'ticker': 'A2M',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 6.769999980926514,
#    'daily_return': 0.01044778711255745,
#    'volume': 919317},
#   {'ticker': 'AAI',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 71.51000213623047,
#    'daily_return': -0.019201775552872058,
#    'volume': 130878},
#   {'ticker': 'AFI',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 6.869999885559082,
#    'daily_return': 0.004385925775139299,
#    'volume': 229403},
#   {'ticker': 'AGL',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 8.869999885559082,
#    'daily_return': -0.011148314213244803,
#    'volume': 1178372},
#   {'ticker': 'AIA',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 7.235000133514404,
#    'daily_return': -0.007544558110620714,
#    'volume': 362542},
#   {'ticker': 'ALD',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 39.84999847412109,
#    'daily_return': 0.0012562622617837693,
#    'volume': 1165503},
#   {'ticker': 'ALK',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 1.8049999475479128,
#    'daily_return': 0.019773992654552597,
#    'volume': 3485885},
#   {'ticker': 'ALL',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 61.15999984741211,
#    'daily_return': -0.009875353825983257,
#    'volume': 399741},
#   {'ticker': 'ALQ',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 22.059999465942383,
#    'daily_return': 0.0036396690342204163,
#    'volume': 451597},
#   {'ticker': 'ALX',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 4.789999961853027,
#    'daily_return': -0.010330617594738856,
#    'volume': 414586},
#   {'ticker': 'AMC',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 67.08999633789062,
#    'daily_return': 0.011000538288500117,
#    'volume': 447197},
#   {'ticker': 'AMP',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 2.384999990463257,
#    'daily_return': -0.0020920980006059464,
#    'volume': 15377361},
#   {'ticker': 'ANN',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 35.14500045776367,
#    'daily_return': -0.003544088414449864,
#    'volume': 172237},
#   {'ticker': 'ANZ',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 37.040000915527344,
#    'daily_return': 0.0008106618577359281,
#    'volume': 3348570},
#   {'ticker': 'APA',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 10.520000457763672,
#    'daily_return': 0.03238477830908382,
#    'volume': 1292980},
#   {'ticker': 'APE',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 22.309999465942383,
#    'daily_return': -0.007562281127921788,
#    'volume': 59872},
#   {'ticker': 'ARB',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 18.924999237060547,
#    'daily_return': -0.02095192386156286,
#    'volume': 50182},
#   {'ticker': 'ARG',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 9.229999542236328,
#    'daily_return': 0.0010845200561737656,
#    'volume': 134919},
#   {'ticker': 'ASB',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 4.139999866485596,
#    'daily_return': -0.02816909764057407,
#    'volume': 754157},
#   {'ticker': 'ASK',
#    'trade_date': Timestamp('2026-08-20 00:00:00'),
#    'close': 1.1449999809265137,
#    'daily_return': 0.0,
#    'volume': 1808127},
#   {'ticker': 'ASX',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 56.119998931884766,
#    'daily_return': -0.023320573859006544,
#    'volume': 381036},
#   {'ticker': 'AUB',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 29.540000915527344,
#    'daily_return': 0.013031586766244718,
#    'volume': 115885},
#   {'ticker': 'AZJ',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 3.630000114440918,
#    'daily_return': 0.008333391834189907,
#    'volume': 2904512},
#   {'ticker': 'BEN',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 10.324999809265137,
#    'daily_return': 0.01126344472952967,
#    'volume': 590097},
#   {'ticker': 'BFL',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 7.960000038146973,
#    'daily_return': 0.002518889267302482,
#    'volume': 864},
#   {'ticker': 'BGA',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 6.460000038146973,
#    'daily_return': -0.03003000207918194,
#    'volume': 425950},
#   {'ticker': 'BGL',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 1.6720000505447388,
#    'daily_return': 0.025766905175445665,
#    'volume': 3064319},
#   {'ticker': 'BHP',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 65.375,
#    'daily_return': -0.005703422053231932,
#    'volume': 6397534},
#   {'ticker': 'BOQ',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 6.349999904632568,
#    'daily_return': 0.0,
#    'volume': 729874},
#   {'ticker': 'BPT',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 0.9120000004768372,
#    'daily_return': 0.018994435656551456,
#    'volume': 5369330},
#   {'ticker': 'BRG',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 32.209999084472656,
#    'daily_return': 0.0009322181172275457,
#    'volume': 57998},
#   {'ticker': 'BSL',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 29.979999542236328,
#    'daily_return': -0.0023294408186835813,
#    'volume': 531571},
#   {'ticker': 'BWP',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 3.690000057220459,
#    'daily_return': -0.008064508376086854,
#    'volume': 704130},
#   {'ticker': 'BXB',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 19.229999542236328,
#    'daily_return': 0.022872357586489533,
#    'volume': 1592688},
#   {'ticker': 'CAR',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 28.170000076293945,
#    'daily_return': -0.010189705464078158,
#    'volume': 633690},
#   {'ticker': 'CBA',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 158.1699981689453,
#    'daily_return': 0.011058525316675505,
#    'volume': 1339268},
#   {'ticker': 'CDA',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 49.2599983215332,
#    'daily_return': 0.007774084392683012,
#    'volume': 405752},
#   {'ticker': 'CEN',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 7.519999980926514,
#    'daily_return': 0.016216200542241266,
#    'volume': 495},
#   {'ticker': 'CGF',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 9.635000228881836,
#    'daily_return': -0.021827425813339074,
#    'volume': 716571},
#   {'ticker': 'CHC',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 20.43000030517578,
#    'daily_return': -0.07598372947982768,
#    'volume': 1193724},
#   {'ticker': 'CIA',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 3.5299999713897705,
#    'daily_return': 0.005698000279445559,
#    'volume': 482610},
#   {'ticker': 'CIP',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 2.9600000381469727,
#    'daily_return': -0.010033435215412778,
#    'volume': 417523},
#   {'ticker': 'CLW',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 3.549999952316284,
#    'daily_return': -0.00837988045505711,
#    'volume': 557110},
#   {'ticker': 'CMM',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 17.71500015258789,
#    'daily_return': 0.007106310341993272,
#    'volume': 1088964},
#   {'ticker': 'CNU',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 8.0,
#    'daily_return': 0.012658215623466695,
#    'volume': 57151},
#   {'ticker': 'COH',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 136.27000427246094,
#    'daily_return': -0.0040199022242009,
#    'volume': 150293},
#   {'ticker': 'COL',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 22.90999984741211,
#    'daily_return': -0.0034797705307747506,
#    'volume': 970677},
#   {'ticker': 'CPU',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 39.40999984741211,
#    'daily_return': 0.0005077547111851377,
#    'volume': 422912},
#   {'ticker': 'CQR',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 3.9700000286102295,
#    'daily_return': -0.009975111717826612,
#    'volume': 447728},
#   {'ticker': 'CSC',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 15.729999542236328,
#    'daily_return': 0.014838680144279248,
#    'volume': 366025},
#   {'ticker': 'CSL',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 167.5500030517578,
#    'daily_return': -0.021320058186612312,
#    'volume': 1446162},
#   {'ticker': 'CTD',
#    'trade_date': Timestamp('2026-08-20 00:00:00'),
#    'close': 16.06999969482422,
#    'daily_return': 0.0,
#    'volume': 0},
#   {'ticker': 'CWY',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 2.6050000190734863,
#    'daily_return': 0.0019231210093542117,
#    'volume': 16796759},
#   {'ticker': 'CYL',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 6.869999885559082,
#    'daily_return': 0.037764351106010174,
#    'volume': 739830},
#   {'ticker': 'DBI',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 5.255000114440918,
#    'daily_return': 0.002862661064497063,
#    'volume': 392292},
#   {'ticker': 'DNL',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 3.714999914169312,
#    'daily_return': 0.0013476754638623856,
#    'volume': 413394},
#   {'ticker': 'DOW',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 6.570000171661377,
#    'daily_return': -0.01646701489580782,
#    'volume': 1048661},
#   {'ticker': 'DRO',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 1.847000002861023,
#    'daily_return': -0.05282053451487878,
#    'volume': 9452035},
#   {'ticker': 'DRR',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 4.375,
#    'daily_return': -0.014639652338461984,
#    'volume': 289635},
#   {'ticker': 'DVP',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 5.159999847412109,
#    'daily_return': -0.0019342802193930142,
#    'volume': 358593},
#   {'ticker': 'DXS',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 5.730000019073486,
#    'daily_return': -0.027164660617823966,
#    'volume': 1570318},
#   {'ticker': 'DYL',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 1.506999969482422,
#    'daily_return': -0.011803283250578445,
#    'volume': 1940714},
#   {'ticker': 'EBO',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 19.170000076293945,
#    'daily_return': -0.020939726711423967,
#    'volume': 57277},
#   {'ticker': 'EDV',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 3.4200000762939453,
#    'daily_return': -0.014409208041508026,
#    'volume': 1344031},
#   {'ticker': 'ELV',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 9.149999618530272,
#    'daily_return': 0.0493118507263508,
#    'volume': 529324},
#   {'ticker': 'EMR',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 7.074999809265137,
#    'daily_return': 0.012160234753967103,
#    'volume': 325691},
#   {'ticker': 'EOS',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 8.869999885559082,
#    'daily_return': -0.0242024492118601,
#    'volume': 1510516},
#   {'ticker': 'EVN',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 15.239999771118164,
#    'daily_return': 0.011280695403884433,
#    'volume': 5415586},
#   {'ticker': 'EVT',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 13.829999923706056,
#    'daily_return': -0.015658381782363562,
#    'volume': 19137},
#   {'ticker': 'FBU',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 3.315000057220459,
#    'daily_return': -0.025000010518466564,
#    'volume': 159766},
#   {'ticker': 'FFM',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 1.9119999408721924,
#    'daily_return': 0.019733301798502634,
#    'volume': 695332},
#   {'ticker': 'FLT',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 12.505000114440918,
#    'daily_return': -0.010680397564478805,
#    'volume': 576612},
#   {'ticker': 'FMG',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 17.84000015258789,
#    'daily_return': -0.006128167447138844,
#    'volume': 4537039},
#   {'ticker': 'FPH',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 36.040000915527344,
#    'daily_return': 0.00839393461028548,
#    'volume': 237554},
#   {'ticker': 'FRW',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 11.989999771118164,
#    'daily_return': 0.006717038180603874,
#    'volume': 166},
#   {'ticker': 'GDG',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 3.865000009536743,
#    'daily_return': 0.01978893098643897,
#    'volume': 1163730},
#   {'ticker': 'GGP',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 13.3149995803833,
#    'daily_return': 0.004147763993372244,
#    'volume': 402148},
#   {'ticker': 'GMD',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 8.1899995803833,
#    'daily_return': 0.02247182850912255,
#    'volume': 4554460},
#   {'ticker': 'GMG',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 27.5,
#    'daily_return': -0.04447535288765481,
#    'volume': 1834594},
#   {'ticker': 'GNE',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 2.240000009536743,
#    'daily_return': 0.018181800448205276,
#    'volume': 10626},
#   {'ticker': 'GPT',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 4.695000171661377,
#    'daily_return': -0.009493586841708201,
#    'volume': 1067307},
#   {'ticker': 'GQG',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 1.434999942779541,
#    'daily_return': -0.03691279624508337,
#    'volume': 1697103},
#   {'ticker': 'HDN',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 1.1519999504089355,
#    'daily_return': 0.006113510566836622,
#    'volume': 1217869},
#   {'ticker': 'HUB',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 76.12000274658203,
#    'daily_return': -0.004707120744640081,
#    'volume': 150626},
#   {'ticker': 'HVN',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 4.53000020980835,
#    'daily_return': -0.010916968281791228,
#    'volume': 446262},
#   {'ticker': 'IAG',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 7.909999847412109,
#    'daily_return': 0.01410251974197485,
#    'volume': 878269},
#   {'ticker': 'IFT',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 12.529999732971191,
#    'daily_return': 0.0,
#    'volume': 56258},
#   {'ticker': 'IGO',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 8.229999542236328,
#    'daily_return': 0.02363178871701277,
#    'volume': 1150427},
#   {'ticker': 'ILU',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 6.900000095367432,
#    'daily_return': -0.021276608696346178,
#    'volume': 1389123},
#   {'ticker': 'IMD',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 3.7100000381469727,
#    'daily_return': -0.03636360258532434,
#    'volume': 2561558},
#   {'ticker': 'JBH',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 69.44999694824219,
#    'daily_return': -0.01082469941804265,
#    'volume': 360257},
#   {'ticker': 'JHX',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 42.790000915527344,
#    'daily_return': -0.0002336056474633308,
#    'volume': 1371466},
#   {'ticker': 'KCN',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 5.360000133514404,
#    'daily_return': 0.02095240638369611,
#    'volume': 785761},
#   {'ticker': 'L1G',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 1.274999976158142,
#    'daily_return': -0.003906246362021082,
#    'volume': 525307},
#   {'ticker': 'LLC',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 2.7799999713897705,
#    'daily_return': -0.003584226021499881,
#    'volume': 1390605},
#   {'ticker': 'LNW',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 126.44000244140624,
#    'daily_return': -0.01534149337684687,
#    'volume': 41166},
#   {'ticker': 'LOV',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 22.979999542236328,
#    'daily_return': -0.023374463593676564,
#    'volume': 91679},
#   {'ticker': 'LSF',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 4.829999923706055,
#    'daily_return': 0.006249944120647832,
#    'volume': 279293},
#   {'ticker': 'LTR',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 1.2599999904632568,
#    'daily_return': 0.04564310837271601,
#    'volume': 19488227},
#   {'ticker': 'LYC',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 16.190000534057617,
#    'daily_return': -0.0018494932531949448,
#    'volume': 1182699},
#   {'ticker': 'MCY',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 5.864999771118164,
#    'daily_return': 0.0025640797829273865,
#    'volume': 4181},
#   {'ticker': 'MEZ',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 4.639999866485596,
#    'daily_return': 0.01978014768746572,
#    'volume': 1340},
#   {'ticker': 'MFF',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 5.349999904632568,
#    'daily_return': 0.01325751743232595,
#    'volume': 146457},
#   {'ticker': 'MFG',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 10.53499984741211,
#    'daily_return': 0.01395567846949497,
#    'volume': 317301},
#   {'ticker': 'MGR',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 1.9019999504089355,
#    'daily_return': 0.0010526180399419438,
#    'volume': 3756928},
#   {'ticker': 'MI6',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 0.8550000190734863,
#    'daily_return': 0.023952144964210387,
#    'volume': 6778339},
#   {'ticker': 'MIN',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 66.82499694824219,
#    'daily_return': 0.01991758809581512,
#    'volume': 582408},
#   {'ticker': 'MND',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 31.899999618530277,
#    'daily_return': 0.003775926031845289,
#    'volume': 47518},
#   {'ticker': 'MPL',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 4.900000095367432,
#    'daily_return': 0.040339714582085184,
#    'volume': 6435975},
#   {'ticker': 'MQG',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 247.72999572753903,
#    'daily_return': -0.018113385925252135,
#    'volume': 393330},
#   {'ticker': 'MSB',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 2.365000009536743,
#    'daily_return': -0.05776891692328323,
#    'volume': 1909232},
#   {'ticker': 'MTS',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 2.9600000381469727,
#    'daily_return': -0.006711402952518042,
#    'volume': 1182533},
#   {'ticker': 'MXT',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 1.9270000457763672,
#    'daily_return': 0.001039009615390718,
#    'volume': 391908},
#   {'ticker': 'NAB',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 38.130001068115234,
#    'daily_return': -0.007806381334328094,
#    'volume': 3188372},
#   {'ticker': 'NEM',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 179.10000610351562,
#    'daily_return': 0.011293054382115475,
#    'volume': 268304},
#   {'ticker': 'NHC',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 5.804999828338623,
#    'daily_return': 0.025618371879075452,
#    'volume': 1027754},
#   {'ticker': 'NHF',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 7.284999847412109,
#    'daily_return': 0.02750348245804246,
#    'volume': 207230},
#   {'ticker': 'NIC',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 0.8450000286102295,
#    'daily_return': 0.0,
#    'volume': 820337},
#   {'ticker': 'NST',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 23.61000061035156,
#    'daily_return': -0.013784457658494675,
#    'volume': 3495515},
#   {'ticker': 'NWH',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 8.265000343322754,
#    'daily_return': 0.08893282966598037,
#    'volume': 1278565},
#   {'ticker': 'NWL',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 21.950000762939453,
#    'daily_return': -0.00723653744890429,
#    'volume': 136684},
#   {'ticker': 'NWS',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 47.310001373291016,
#    'daily_return': 0.0014817885761448935,
#    'volume': 10026},
#   {'ticker': 'NXG',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 14.404999732971191,
#    'daily_return': -0.023389848612122566,
#    'volume': 363521},
#   {'ticker': 'NXT',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 13.699999809265137,
#    'daily_return': -0.014388475881575769,
#    'volume': 508598},
#   {'ticker': 'OBM',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 1.597000002861023,
#    'daily_return': 0.007570955473338303,
#    'volume': 2752185},
#   {'ticker': 'ORA',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 1.5019999742507937,
#    'daily_return': -0.011842109803677836,
#    'volume': 1940936},
#   {'ticker': 'ORG',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 11.984999656677246,
#    'daily_return': -0.004568131673591491,
#    'volume': 1191697},
#   {'ticker': 'ORI',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 22.170000076293945,
#    'daily_return': 0.0004512738696162977,
#    'volume': 412800},
#   {'ticker': 'PDI',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 0.9049999713897704,
#    'daily_return': -0.016304396768935914,
#    'volume': 3474247},
#   {'ticker': 'PDN',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 10.479999542236328,
#    'daily_return': 0.007692300638503458,
#    'volume': 1497912},
#   {'ticker': 'PLS',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 4.96999979019165,
#    'daily_return': 0.028985480061493263,
#    'volume': 12818465},
#   {'ticker': 'PME',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 195.94000244140625,
#    'daily_return': -0.048881085063548046,
#    'volume': 118095},
#   {'ticker': 'PMV',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 11.520000457763672,
#    'daily_return': -0.015384560208191234,
#    'volume': 140916},
#   {'ticker': 'PNI',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 18.030000686645508,
#    'daily_return': -0.005515635893546533,
#    'volume': 185460},
#   {'ticker': 'PPT',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 19.61000061035156,
#    'daily_return': -0.004568535487430414,
#    'volume': 66769},
#   {'ticker': 'PRN',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 2.440000057220459,
#    'daily_return': -0.004081628681073313,
#    'volume': 451293},
#   {'ticker': 'PRU',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 6.159999847412109,
#    'daily_return': 0.004893920458585166,
#    'volume': 1500458},
#   {'ticker': 'PXA',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 8.095000267028809,
#    'daily_return': 0.006840834009544494,
#    'volume': 116594},
#   {'ticker': 'QAN',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 9.270000457763672,
#    'daily_return': -0.009615299381915077,
#    'volume': 1538724},
#   {'ticker': 'QBE',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 22.190000534057617,
#    'daily_return': 0.018824602134356327,
#    'volume': 1473080},
#   {'ticker': 'RDX',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 3.384999990463257,
#    'daily_return': -0.057103044180291995,
#    'volume': 497609},
#   {'ticker': 'REA',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 177.0,
#    'daily_return': -0.009734840772569031,
#    'volume': 45396},
#   {'ticker': 'REG',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 6.360000133514404,
#    'daily_return': -0.0031347931924397,
#    'volume': 185704},
#   {'ticker': 'REH',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 16.770000457763672,
#    'daily_return': -0.023864949949307657,
#    'volume': 806771},
#   {'ticker': 'RGN',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 2.255000114440918,
#    'daily_return': -0.00660787075402236,
#    'volume': 624540},
#   {'ticker': 'RHC',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 45.09999847412109,
#    'daily_return': 0.01007831876514853,
#    'volume': 433044},
#   {'ticker': 'RIO',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 175.25,
#    'daily_return': 0.012771652794812516,
#    'volume': 804950},
#   {'ticker': 'RMD',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 32.1349983215332,
#    'daily_return': 0.00015553231409404233,
#    'volume': 778832},
#   {'ticker': 'RMS',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 3.964999914169312,
#    'daily_return': 0.011479550254986481,
#    'volume': 4409291},
#   {'ticker': 'RRL',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 8.460000038146973,
#    'daily_return': 0.027946598870423056,
#    'volume': 2699937},
#   {'ticker': 'RSG',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 1.312000036239624,
#    'daily_return': 0.037154190574097745,
#    'volume': 3070315},
#   {'ticker': 'RWC',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 4.425000190734863,
#    'daily_return': 0.005681839733084004,
#    'volume': 3677130},
#   {'ticker': 'RYM',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 1.774999976158142,
#    'daily_return': 0.008522719191002448,
#    'volume': 23},
#   {'ticker': 'S32',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 4.914999961853027,
#    'daily_return': 0.005112494079759333,
#    'volume': 5258621},
#   {'ticker': 'SCG',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 3.630000114440918,
#    'daily_return': -0.002747250048093064,
#    'volume': 1483233},
#   {'ticker': 'SDF',
#    'trade_date': Timestamp('2026-08-20 00:00:00'),
#    'close': 5.650000095367432,
#    'daily_return': -0.005281643288353122,
#    'volume': 8273089},
#   {'ticker': 'SEK',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 14.324999809265137,
#    'daily_return': -0.005208320225829954,
#    'volume': 539761},
#   {'ticker': 'SFR',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 21.604999542236328,
#    'daily_return': 0.006287854364199541,
#    'volume': 563751},
#   {'ticker': 'SGH',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 40.69499969482422,
#    'daily_return': -0.005984341477845656,
#    'volume': 222262},
#   {'ticker': 'SGM',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 23.56999969482422,
#    'daily_return': 0.014199652622895798,
#    'volume': 384670},
#   {'ticker': 'SGP',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 4.619999885559082,
#    'daily_return': -0.008583683082144522,
#    'volume': 4570706},
#   {'ticker': 'SHL',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 20.84000015258789,
#    'daily_return': -0.025257204367418185,
#    'volume': 1435301},
#   {'ticker': 'SIG',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 2.8949999809265137,
#    'daily_return': -0.0017241773367200341,
#    'volume': 2564418},
#   {'ticker': 'SMR',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 2.7149999141693115,
#    'daily_return': 0.020676626527794673,
#    'volume': 348512},
#   {'ticker': 'SNZ',
#    'trade_date': Timestamp('2026-08-20 00:00:00'),
#    'close': 6.579999923706055,
#    'daily_return': -0.013493276095717488,
#    'volume': 193},
#   {'ticker': 'SOL',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 43.97499847412109,
#    'daily_return': -0.00845546816013576,
#    'volume': 83335},
#   {'ticker': 'SPK',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 1.8350000381469729,
#    'daily_return': 0.008241750144279303,
#    'volume': 799268},
#   {'ticker': 'STO',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 8.444999694824219,
#    'daily_return': -0.0005917295329919137,
#    'volume': 7075895},
#   {'ticker': 'SUL',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 13.529999732971191,
#    'daily_return': -0.06366782618945466,
#    'volume': 342500},
#   {'ticker': 'SUN',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 18.209999084472656,
#    'daily_return': 0.015616217207539584,
#    'volume': 1209186},
#   {'ticker': 'TAH',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 0.8899999856948853,
#    'daily_return': -0.02197806588435236,
#    'volume': 510107},
#   {'ticker': 'TCL',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 13.920000076293944,
#    'daily_return': -0.002865326772473198,
#    'volume': 1133254},
#   {'ticker': 'TLC',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 5.190000057220459,
#    'daily_return': -0.001923029309897406,
#    'volume': 2925929},
#   {'ticker': 'TLS',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 4.71999979019165,
#    'daily_return': 0.002123089588893512,
#    'volume': 9372430},
#   {'ticker': 'TLX',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 16.049999237060547,
#    'daily_return': -0.07652474038712154,
#    'volume': 3092460},
#   {'ticker': 'TNE',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 32.0099983215332,
#    'daily_return': -0.013863240161171575,
#    'volume': 231364},
#   {'ticker': 'TPG',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 3.704999923706055,
#    'daily_return': 0.04957505771519499,
#    'volume': 1605211},
#   {'ticker': 'TUA',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 2.069999933242798,
#    'daily_return': 0.004854364437391068,
#    'volume': 371999},
#   {'ticker': 'TWE',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 5.610000133514404,
#    'daily_return': 0.0035778140215712018,
#    'volume': 1131496},
#   {'ticker': 'VAU',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 6.659999847412109,
#    'daily_return': 0.02619415751761367,
#    'volume': 6819543},
#   {'ticker': 'VCX',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 2.6050000190734863,
#    'daily_return': -0.0019156613882373996,
#    'volume': 1618513},
#   {'ticker': 'VEA',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 2.7950000762939453,
#    'daily_return': -0.005338030886491207,
#    'volume': 1041168},
#   {'ticker': 'VGN',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 2.6549999713897705,
#    'daily_return': -0.013011184046908042,
#    'volume': 141462},
#   {'ticker': 'VNT',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 5.565000057220459,
#    'daily_return': -0.004472288852417572,
#    'volume': 454895},
#   {'ticker': 'WAF',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 3.7799999713897705,
#    'daily_return': 0.007999992370605558,
#    'volume': 1929961},
#   {'ticker': 'WAM',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 1.5499999523162842,
#    'daily_return': 0.00323624295826086,
#    'volume': 174705},
#   {'ticker': 'WBC',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 33.83000183105469,
#    'daily_return': 0.00029574619517225287,
#    'volume': 2541207},
#   {'ticker': 'WDS',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 34.08000183105469,
#    'daily_return': 0.01398396941886304,
#    'volume': 3747099},
#   {'ticker': 'WES',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 82.5199966430664,
#    'daily_return': -0.021579319111335593,
#    'volume': 1099142},
#   {'ticker': 'WGX',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 6.224999904632568,
#    'daily_return': -0.0008025865851700731,
#    'volume': 1176097},
#   {'ticker': 'WHC',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 7.755000114440918,
#    'daily_return': 0.016382699623217478,
#    'volume': 2435663},
#   {'ticker': 'WLE',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 1.340000033378601,
#    'daily_return': 0.0,
#    'volume': 466889},
#   {'ticker': 'WOR',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 10.850000381469728,
#    'daily_return': -0.007319297481461873,
#    'volume': 305656},
#   {'ticker': 'WOW',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 38.834999084472656,
#    'daily_return': -0.0039754446607204175,
#    'volume': 819077},
#   {'ticker': 'WTC',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 41.7599983215332,
#    'daily_return': -0.03310952421034463,
#    'volume': 1114097},
#   {'ticker': 'XRO',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 85.7300033569336,
#    'daily_return': 0.005158898307927595,
#    'volume': 537201},
#   {'ticker': 'YAL',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 5.885000228881836,
#    'daily_return': 0.018166092605897743,
#    'volume': 2325525},
#   {'ticker': 'ZIM',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 15.68000030517578,
#    'daily_return': -0.021223479580059545,
#    'volume': 4902},
#   {'ticker': 'ZIP',
#    'trade_date': Timestamp('2026-08-21 00:00:00'),
#    'close': 2.7149999141693115,
#    'daily_return': -0.10983607979815246,
#    'volume': 27767156}],
#  'trino_query': 'SELECT ticker, run_date, row_count, start_trade_date, end_trade_date, min_close, max_close, latest_close, average_volume, generated_at FROM demo.asx_ohlcv_summary ORDER BY ticker',
#  'trino_row_count': 201,
#  'trino_error': None,
#  'trino_rows': [{'ticker': '360.AX',
#    'run_date': '2026-08-21',
#    'row_count': 1846,
#    'start_trade_date': '2019-05-10',
#    'end_trade_date': '2026-08-21',
#    'min_close': 1.600000023841858,
#    'max_close': 55.43999862670898,
#    'latest_close': 20.93000030517578,
#    'average_volume': 774127.9918743229,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': '4DX.AX',
#    'run_date': '2026-08-21',
#    'row_count': 1529,
#    'start_trade_date': '2020-08-07',
#    'end_trade_date': '2026-08-21',
#    'min_close': 0.2300000041723251,
#    'max_close': 6.800000190734863,
#    'latest_close': 3.930000066757202,
#    'average_volume': 1776842.9849574885,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'A2M.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 1.725000023841858,
#    'max_close': 19.940000534057617,
#    'latest_close': 6.769999980926514,
#    'average_volume': 3763118.1351778656,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'AAI.AX',
#    'run_date': '2026-08-21',
#    'row_count': 528,
#    'start_trade_date': '2024-07-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 36.43000030517578,
#    'max_close': 116.8499984741211,
#    'latest_close': 71.51000213623047,
#    'average_volume': 237562.64772727274,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'AFI.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 4.820000171661377,
#    'max_close': 8.850000381469727,
#    'latest_close': 6.869999885559082,
#    'average_volume': 413271.83162055333,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'AGL.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 5.099999904632568,
#    'max_close': 28.440000534057617,
#    'latest_close': 8.869999885559082,
#    'average_volume': 2668892.523320158,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'AIA.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 4.489999771118164,
#    'max_close': 9.329999923706056,
#    'latest_close': 7.235000133514404,
#    'average_volume': 487806.6980237154,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'ALD.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 19.0,
#    'max_close': 41.27999877929688,
#    'latest_close': 39.84999847412109,
#    'average_volume': 1010059.1735177865,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'ALK.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 0.1537880003452301,
#    'max_close': 1.875,
#    'latest_close': 1.8049999475479128,
#    'average_volume': 2187973.8573122527,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'ALL.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 13.993926048278809,
#    'max_close': 78.51000213623047,
#    'latest_close': 61.15999984741211,
#    'average_volume': 1720445.5308300394,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'ALQ.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 4.639999866485596,
#    'max_close': 26.040000915527344,
#    'latest_close': 22.059999465942383,
#    'average_volume': 1381573.3264822133,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'ALX.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 3.7989869117736816,
#    'max_close': 7.942913055419922,
#    'latest_close': 4.789999961853027,
#    'average_volume': 2998515.7083003954,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'AMC.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 50.70000076293945,
#    'max_close': 93.8499984741211,
#    'latest_close': 67.08999633789062,
#    'average_volume': 601258.495256917,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'AMP.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 0.8500000238418579,
#    'max_close': 5.46999979019165,
#    'latest_close': 2.384999990463257,
#    'average_volume': 11796472.361660078,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'ANN.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 20.88999938964844,
#    'max_close': 43.5099983215332,
#    'latest_close': 35.14500045776367,
#    'average_volume': 487726.9166007905,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'ANZ.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 13.988417625427246,
#    'max_close': 40.88999938964844,
#    'latest_close': 37.040000915527344,
#    'average_volume': 5902597.381422925,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'APA.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 6.559999942779541,
#    'max_close': 12.229999542236328,
#    'latest_close': 10.520000457763672,
#    'average_volume': 2629370.664822134,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'APE.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 2.900000095367432,
#    'max_close': 34.72999954223633,
#    'latest_close': 22.309999465942383,
#    'average_volume': 435008.63399209484,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'ARB.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 10.8100004196167,
#    'max_close': 54.52999877929688,
#    'latest_close': 18.924999237060547,
#    'average_volume': 209175.12055335968,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'ARG.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 5.539999961853027,
#    'max_close': 10.399999618530272,
#    'latest_close': 9.229999542236328,
#    'average_volume': 226945.55533596838,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'ASB.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 1.159999966621399,
#    'max_close': 8.760000228881836,
#    'latest_close': 4.139999866485596,
#    'average_volume': 1263161.7272727273,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'ASK.AX',
#    'run_date': '2026-08-21',
#    'row_count': 25,
#    'start_trade_date': '2026-07-17',
# ...
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'RYM.AX',
#    'run_date': '2026-08-21',
#    'row_count': 223,
#    'start_trade_date': '2025-10-06',
#    'end_trade_date': '2026-08-21',
#    'min_close': 1.6200000047683716,
#    'max_close': 2.609999895095825,
#    'latest_close': 1.774999976158142,
#    'average_volume': 8486.37668161435,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'S32.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 1.6649999618530271,
#    'max_close': 5.360000133514404,
#    'latest_close': 4.914999961853027,
#    'average_volume': 19366971.74624506,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'SCG.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 1.4299999475479126,
#    'max_close': 5.139999866485596,
#    'latest_close': 3.630000114440918,
#    'average_volume': 13134192.527667984,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'SDF.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2529,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-20',
#    'min_close': 2.0299999713897705,
#    'max_close': 6.630000114440918,
#    'latest_close': 5.650000095367432,
#    'average_volume': 2390656.5650454727,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'SEK.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 11.81999969482422,
#    'max_close': 35.7400016784668,
#    'latest_close': 14.324999809265137,
#    'average_volume': 1118754.8537549407,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'SFR.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 2.5881330966949463,
#    'max_close': 21.604999542236328,
#    'latest_close': 21.604999542236328,
#    'average_volume': 1694720.4166007906,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'SGH.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 7.21999979019165,
#    'max_close': 55.2400016784668,
#    'latest_close': 40.69499969482422,
#    'average_volume': 585291.7288537549,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'SGM.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 5.739999771118164,
#    'max_close': 29.989999771118164,
#    'latest_close': 23.56999969482422,
#    'average_volume': 827930.4703557312,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'SGP.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 1.7949999570846558,
#    'max_close': 6.730000019073486,
#    'latest_close': 4.619999885559082,
#    'average_volume': 7303610.446245059,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'SHL.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 18.38999938964844,
#    'max_close': 46.709999084472656,
#    'latest_close': 20.84000015258789,
#    'average_volume': 1193824.509486166,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'SIG.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 0.3929249942302704,
#    'max_close': 3.2699999809265137,
#    'latest_close': 2.8949999809265137,
#    'average_volume': 6654455.077865613,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'SMR.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 0.2622720003128052,
#    'max_close': 4.190000057220459,
#    'latest_close': 2.7149999141693115,
#    'average_volume': 1121856.171541502,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'SNZ.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2529,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-20',
#    'min_close': 3.890000104904175,
#    'max_close': 15.100000381469728,
#    'latest_close': 6.579999923706055,
#    'average_volume': 2239.5935152234083,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'SOL.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 14.449999809265137,
#    'max_close': 46.91999816894531,
#    'latest_close': 43.97499847412109,
#    'average_volume': 418521.9276679842,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'SPK.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 1.4500000476837158,
#    'max_close': 5.070000171661377,
#    'latest_close': 1.8350000381469729,
#    'average_volume': 1184555.557312253,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'STO.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 2.75,
#    'max_close': 9.0,
#    'latest_close': 8.444999694824219,
#    'average_volume': 9085177.321343873,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'SUL.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 3.544472932815552,
#    'max_close': 18.84000015258789,
#    'latest_close': 13.529999732971191,
#    'average_volume': 824877.9288537549,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'SUN.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 9.023615837097168,
#    'max_close': 24.45071029663086,
#    'latest_close': 18.209999084472656,
#    'average_volume': 2725980.191304348,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'TAH.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 0.2951720058917999,
#    'max_close': 1.1649999618530271,
#    'latest_close': 0.8899999856948853,
#    'average_volume': 27347679.742687747,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'TCL.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 9.301868438720703,
#    'max_close': 16.233781814575195,
#    'latest_close': 13.920000076293944,
#    'average_volume': 5140724.537944664,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'TLC.AX',
#    'run_date': '2026-08-21',
#    'row_count': 1076,
#    'start_trade_date': '2022-05-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 3.920000076293945,
#    'max_close': 5.96999979019165,
#    'latest_close': 5.190000057220459,
#    'average_volume': 4230650.525092937,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'TLS.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 2.619999885559082,
#    'max_close': 5.550000190734863,
#    'latest_close': 4.71999979019165,
#    'average_volume': 25672467.469960473,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'TLX.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2218,
#    'start_trade_date': '2017-11-15',
#    'end_trade_date': '2026-08-21',
#    'min_close': 0.4799999892711639,
#    'max_close': 31.13999938964844,
#    'latest_close': 16.049999237060547,
#    'average_volume': 1058319.821911632,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'TNE.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 4.119999885559082,
#    'max_close': 42.61000061035156,
#    'latest_close': 32.0099983215332,
#    'average_volume': 955122.8075098814,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'TPG.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 3.509999990463257,
#    'max_close': 11.947538375854492,
#    'latest_close': 3.704999923706055,
#    'average_volume': 1771169.9395256918,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'TUA.AX',
#    'run_date': '2026-08-21',
#    'row_count': 1557,
#    'start_trade_date': '2020-06-30',
#    'end_trade_date': '2026-08-21',
#    'min_close': 0.4749999940395355,
#    'max_close': 8.319999694824219,
#    'latest_close': 2.069999933242798,
#    'average_volume': 712408.3134232499,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'TWE.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 3.369999885559082,
#    'max_close': 19.645919799804688,
#    'latest_close': 5.610000133514404,
#    'average_volume': 3257049.728853755,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'VAU.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 0.1837369948625564,
#    'max_close': 6.659999847412109,
#    'latest_close': 6.659999847412109,
#    'average_volume': 1957261.7106719369,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'VCX.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 0.9649999737739564,
#    'max_close': 3.380000114440918,
#    'latest_close': 2.6050000190734863,
#    'average_volume': 11558456.05889328,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'VEA.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2054,
#    'start_trade_date': '2018-07-13',
#    'end_trade_date': '2026-08-21',
#    'min_close': 1.4299999475479126,
#    'max_close': 3.819999933242798,
#    'latest_close': 2.7950000762939453,
#    'average_volume': 4498761.53067186,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'VGN.AX',
#    'run_date': '2026-08-21',
#    'row_count': 297,
#    'start_trade_date': '2025-06-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 2.1600000858306885,
#    'max_close': 3.7200000286102295,
#    'latest_close': 2.6549999713897705,
#    'average_volume': 1802264.2356902356,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'VNT.AX',
#    'run_date': '2026-08-21',
#    'row_count': 1201,
#    'start_trade_date': '2021-11-19',
#    'end_trade_date': '2026-08-21',
#    'min_close': 1.9600000381469729,
#    'max_close': 6.760000228881836,
#    'latest_close': 5.565000057220459,
#    'average_volume': 2639334.6994171524,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'WAF.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 0.1800000071525573,
#    'max_close': 3.910000085830689,
#    'latest_close': 3.7799999713897705,
#    'average_volume': 3303122.5798418974,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'WAM.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 1.3949999809265137,
#    'max_close': 2.5899999141693115,
#    'latest_close': 1.5499999523162842,
#    'average_volume': 843872.843083004,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'WBC.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 14.100000381469728,
#    'max_close': 42.95000076293945,
#    'latest_close': 33.83000183105469,
#    'average_volume': 6651132.0177865615,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'WDS.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 15.270000457763672,
#    'max_close': 39.15999984741211,
#    'latest_close': 34.08000183105469,
#    'average_volume': 4025604.551778656,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'WES.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 28.509614944458008,
#    'max_close': 94.76000213623048,
#    'latest_close': 82.5199966430664,
#    'average_volume': 2119461.538735178,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'WGX.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2456,
#    'start_trade_date': '2016-12-06',
#    'end_trade_date': '2026-08-21',
#    'min_close': 0.7200000286102295,
#    'max_close': 8.050000190734863,
#    'latest_close': 6.224999904632568,
#    'average_volume': 2598066.227605863,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'WHC.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 0.8450000286102295,
#    'max_close': 10.960000038146973,
#    'latest_close': 7.755000114440918,
#    'average_volume': 7798635.241501977,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'WLE.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 0.7900000214576721,
#    'max_close': 1.6200000047683716,
#    'latest_close': 1.340000033378601,
#    'average_volume': 845452.4181818182,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'WOR.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 4.900000095367432,
#    'max_close': 19.903940200805664,
#    'latest_close': 10.850000381469728,
#    'average_volume': 1785218.3308300395,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'WOW.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 18.907161712646484,
#    'max_close': 41.9900016784668,
#    'latest_close': 38.834999084472656,
#    'average_volume': 2817652.719367589,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'WTC.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 4.800000190734863,
#    'max_close': 138.92999267578125,
#    'latest_close': 41.7599983215332,
#    'average_volume': 786011.5529644269,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'XRO.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 16.079999923706055,
#    'max_close': 194.2100067138672,
#    'latest_close': 85.7300033569336,
#    'average_volume': 462684.1418972332,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'YAL.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 1.8899999856948853,
#    'max_close': 11.852108001708984,
#    'latest_close': 5.885000228881836,
#    'average_volume': 1334255.0415019763,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'ZIM.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 3.5999999046325684,
#    'max_close': 34.90999984741211,
#    'latest_close': 15.68000030517578,
#    'average_volume': 8678.761264822135,
#    'generated_at': '2026-08-21T02:59:16Z'},
#   {'ticker': 'ZIP.AX',
#    'run_date': '2026-08-21',
#    'row_count': 2530,
#    'start_trade_date': '2016-08-24',
#    'end_trade_date': '2026-08-21',
#    'min_close': 0.2549999952316284,
#    'max_close': 13.920000076293944,
#    'latest_close': 2.7149999141693115,
#    'average_volume': 9008263.968379447,
#    'generated_at': '2026-08-21T02:59:16Z'}]}
